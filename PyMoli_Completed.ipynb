# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head(50)
# Out:
#     Purchase ID               SN  Age                 Gender  Item ID  \
# 0             0          Lisim78   20                   Male      108
# 1             1      Lisovynya38   40                   Male      143
# 2             2       Ithergue48   24                   Male       92
# 3             3    Chamassasya86   24                   Male      100
# 4             4        Iskosia90   23                   Male      131
# 5             5          Yalae81   22                   Male       81
# 6             6        Itheria73   36                   Male      169
# 7             7      Iskjaskst81   20                   Male      162
# 8             8        Undjask33   22                   Male       21
# 9             9      Chanosian48   35  Other / Non-Disclosed      136
# 10           10        Inguron55   23                   Male       95
# 11           11     Haisrisuir60   23                   Male      162
# 12           12     Saelaephos52   21                   Male      116
# 13           13      Assjaskan73   22                   Male        4
# 14           14      Saesrideu94   35                   Male      165
# 15           15        Lisassa64   21                 Female       98
# 16           16        Lisirra25   20                   Male       40
# 17           17        Zontibe81   21                   Male      161
# 18           18        Reunasu60   22                 Female       82
# 19           19        Chamalo71   30                   Male       89
# 20           20     Iathenudil29   20                   Male       57
# 21           21    Phiarithdeu40   20                   Male      168
# 22           22     Siarithria38   38  Other / Non-Disclosed       24
# 23           23         Eyrian71   40                   Male      151
# 24           24          Siala43   30                   Male      141
# 25           25        Lisirra87   29                   Male      178
# 26           26       Lirtossa84   11                   Male       71
# 27           27          Eusri44    7                   Male       96
# 28           28           Aela59   21                   Male      119
# 29           29          Tyida79   24                   Male       37
# 30           30           Idai61   19                   Male      140
# 31           31      Farusrian86   37                   Male      179
# 32           32       Aeralria27   10                   Male      133
# 33           33     Haillyrgue51    7                   Male       44
# 34           34         Sondim73   19                   Male      160
# 35           35       Jeyciman68   22                   Male       53
# 36           36       Idaisuir85   30                   Male       76
# 37           37        Seuthep89    8                   Male       73
# 38           38         Reulae52   10                 Female      116
# 39           39     Sondilsaya62   21                   Male      172
# 40           40  Aerithriaphos45   20                   Male      143
# 41           41        Assosia88   20                 Female        7
# 42           42    Aidaillodeu39   18                   Male       72
# 43           43          Aelly27   24                   Male      116
# 44           44        Tyeosri53   24                   Male        9
# 45           45        Haerith37   23                   Male      181
# 46           46        Yasrisu92   27                   Male      102
# 47           47       Chanuchi25   20                   Male      170
# 48           48           Asur96   20                   Male      138
# 49           49      Iaralrgue74   33                   Male      110
#
#                                        Item Name  Price
# 0      Extraction, Quickblade Of Trembling Hands   3.53
# 1                              Frenzied Scimitar   1.56
# 2                                   Final Critic   4.88
# 3                                    Blindscythe   3.27
# 4                                           Fury   1.44
# 5                                      Dreamkiss   3.61
# 6         Interrogator, Blood Blade of the Queen   2.18
# 7                                  Abyssal Shard   2.67
# 8                                      Souleater   1.10
# 9                   Ghastly Adamantite Protector   3.58
# 10                         Singed Onyx Warscythe   4.74
# 11                                 Abyssal Shard   2.67
# 12                       Renewed Skeletal Katana   4.18
# 13                            Bloodlord's Fetish   1.70
# 14                   Bone Crushing Silver Skewer   4.86
# 15                   Deadline, Voice Of Subtlety   2.89
# 16                                 Second Chance   2.52
# 17                                        Devine   1.76
# 18                                       Nirvana   4.90
# 19             Blazefury, Protector of Delusions   4.64
# 20               Despair, Favor of Due Diligence   4.60
# 21           Sun Strike, Jaws of Twisted Visions   1.48
# 22                                 Warped Fetish   3.81
# 23                                     Severance   3.40
# 24                                    Persuasion   3.19
# 25  Oathbreaker, Last Hope of the Breaking Storm   4.23
# 26                                        Demise   1.61
# 27                   Blood-Forged Skeletal Spine   3.09
# 28     Stormbringer, Dark Blade of Ending Misery   4.32
# 29           Shadow Strike, Glory of Ending Hope   3.16
# 30                                       Striker   2.94
# 31               Wolf, Promise of the Moonwalker   4.48
# 32                              Faith's Scimitar   4.09
# 33                         Bonecarvin Battle Axe   2.38
# 34                                    Azurewrath   4.40
# 35                             Vengeance Cleaver   2.05
# 36                      Haunted Bronzed Bludgeon   3.15
# 37                                   Ritual Mace   2.05
# 38                       Renewed Skeletal Katana   4.18
# 39                            Blade of the Grave   3.14
# 40                             Frenzied Scimitar   1.56
# 41                  Thorn, Satchel of Dark Souls   1.33
# 42                                 Winter's Bite   3.77
# 43                       Renewed Skeletal Katana   4.18
# 44             Thorn, Conqueror of the Corrupted   2.73
# 45                                 Reaper's Toll   1.66
# 46                                       Avenger   3.44
# 47                                   Shadowsteel   3.97
# 48                Peacekeeper, Wit of Dark Magic   4.74
# 49                                    Suspension   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
total_players_count = len(purchase_data["SN"].unique())
total_players_count
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
number_of_items = len(purchase_data["Item ID"].unique())

avg = purchase_data["Price"].mean()

number_of_purchases = purchase_data["Purchase ID"].count()
number_of_purchases

total_revenue = purchase_data["Price"].sum()
total_revenue

summary_df =pd.DataFrame({"Number Of Items":[number_of_items],
                          "Average Price":[avg],
                          "Total Purchases":[number_of_purchases],
                          "Total Revenue":[total_revenue]})

summary_df["Average Price"] = summary_df["Average Price"].map("${:,.2f}".format)
summary_df["Total Revenue"] = summary_df["Total Revenue"].map("${:,.2f}".format)

summary_df.head()
# Out:
#    Number Of Items Average Price  Total Purchases Total Revenue
# 0              183         $3.05              780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender_demo = purchase_data.copy()

gender_demo.drop_duplicates(subset="SN",keep='first', inplace=True)

players_count = gender_demo["Gender"].value_counts()
players_demo_df = pd.DataFrame(players_count)

players_demo_df = players_demo_df.rename(columns={"Gender":"Count"})
players_demo_df["Percentage"] = round((players_demo_df["Count"]/total_players_count)*100 ,2)

players_demo_df["Percentage"]  = players_demo_df["Percentage"] .map("{:,.2f}%".format)
players_demo_df.head(50)
# Out:
#                        Count Percentage
# Male                     484     84.03%
# Female                    81     14.06%
# Other / Non-Disclosed     11      1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
gender_data = purchase_data.groupby("Gender")

purchase_gender_count = gender_data["Purchase ID"].count()
purchase_gender_count 


gender_purchase_avg = gender_data["Price"].mean()
gender_purchase_total= gender_data["Price"].sum()


gender_purchase_avgpp =(gender_purchase_total)/players_demo_df["Count"]


gender_purchase_analysis = pd.DataFrame({"Total Purchase":(gender_purchase_total),
                                        "Purchase Average":(gender_purchase_avg),
                                        "Average Purchase Per Person":(gender_purchase_avgpp),
                                        "Count":(purchase_gender_count )})


gender_purchase_analysis["Purchase Average"] = gender_purchase_analysis["Purchase Average"].map("${:,.2f}".format)
gender_purchase_analysis["Total Purchase"] = gender_purchase_analysis["Total Purchase"].map("${:,.2f}".format)

gender_purchase_analysis["Average Purchase Per Person"] =gender_purchase_analysis["Average Purchase Per Person"].map("${:,.2f}".format)
gender_purchase_analysis.head()
# Out:
#                       Total Purchase Purchase Average  \
# Gender
# Female                       $361.94            $3.20
# Male                       $1,967.64            $3.02
# Other / Non-Disclosed         $50.19            $3.35
#
#                       Average Purchase Per Person  Count
# Gender
# Female                                      $4.47    113
# Male                                        $4.07    652
# Other / Non-Disclosed                       $4.56     15

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
purchase_data.describe()

bins = [0,10,14,19,24, 29,34,39,40]
age_group_names =["Grp1","Grp2","Grp3","Grp4","Grp5","Grp6","Grp7","Grp8"]

purchase_data["Age Group"] = pd.cut(purchase_data["Age"],bins, labels=age_group_names, include_lowest=True)

group_total_count = purchase_data["Age Group"].count()

age_group_count = purchase_data["Age Group"].value_counts()

age_group_analysis = pd.DataFrame(age_group_count)
age_group_analysis

age_group_analysis = age_group_analysis.rename(columns={"Age Group":"Count"})

age_group_analysis["Age Group Percentage"]= round((age_group_analysis["Count"]/group_total_count)*100,2)


age_group_analysis["Age Group Percentage"]  = age_group_analysis["Age Group Percentage"].map("{:,.2f}%".format)
age_group_analysis.head()
# Out:
#       Count Age Group Percentage
# Grp4    365               47.22%
# Grp3    136               17.59%
# Grp5    101               13.07%
# Grp6     73                9.44%
# Grp7     41                5.30%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
agegrouped_purchase_data = purchase_data.groupby(["Age Group"])

agegrouped_purchase_count = agegrouped_purchase_data["Purchase ID"].count()

agegrouped_purchase_avg = agegrouped_purchase_data["Price"].mean()
agegrouped_purchase_total = agegrouped_purchase_data["Price"].sum()

agegrouped_purchase_avgpp = agegrouped_purchase_total/group_total_count

agegrouped_purchase_analysis = pd.DataFrame({"Average Purchase Price":(agegrouped_purchase_avg),
                                            "Purchase Total":(agegrouped_purchase_total),
                                            "Average Purchase Per Person":(agegrouped_purchase_avgpp),
                                            "Count":(agegrouped_purchase_count)})

agegrouped_purchase_analysis["Average Purchase Price"] = agegrouped_purchase_analysis["Average Purchase Price"].map("${:,.2f}".format)
agegrouped_purchase_analysis["Purchase Total"] = agegrouped_purchase_analysis["Purchase Total"].map("${:,.2f}".format)

agegrouped_purchase_analysis["Average Purchase Per Person"]= agegrouped_purchase_analysis["Average Purchase Per Person"].map("${:,.2f}".format)

agegrouped_purchase_analysis.head()
# Out:
#           Average Purchase Price Purchase Total Average Purchase Per Person  \
# Age Group
# Grp1                       $3.40        $108.96                       $0.14
# Grp2                       $2.68         $50.95                       $0.07
# Grp3                       $3.04        $412.89                       $0.53
# Grp4                       $3.05      $1,114.06                       $1.44
# Grp5                       $2.90        $293.00                       $0.38
#
#            Count
# Age Group
# Grp1          32
# Grp2          19
# Grp3         136
# Grp4         365
# Grp5         101

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
sorted_top_spenders = agegrouped_purchase_analysis.sort_values("Purchase Total",ascending=False)

top_spenders =sorted_top_spenders.max()



sorted_top_spenders.head()
# Out:
#           Average Purchase Price Purchase Total Average Purchase Per Person  \
# Age Group
# Grp2                       $2.68         $50.95                       $0.07
# Grp3                       $3.04        $412.89                       $0.53
# Grp5                       $2.90        $293.00                       $0.38
# Grp6                       $2.93        $214.00                       $0.28
# Grp8                       $2.79         $16.71                       $0.02
#
#            Count
# Age Group
# Grp2          19
# Grp3         136
# Grp5         101
# Grp6          73
# Grp8           6

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
popular_item = purchase_data[["Item ID", "Item Name","Price"]]

grouped_popular_item = popular_item.groupby(["Item ID", "Item Name"])

item_price_count = grouped_popular_item["Price"].count()


popular_item_summary =pd.DataFrame(item_price_count)

popular_item_summary["Item Price"] = grouped_popular_item["Price"].max()

popular_item_summary["Total Purchase"] = grouped_popular_item["Price"].sum()

popular_item_summary = popular_item_summary.rename(columns={"Price":"Purchase Count"})


popular_item_summary["Total Purchase"] = popular_item_summary["Total Purchase"].map("${:,.2f}".format)
popular_item_summary["Item Price"] = popular_item_summary["Item Price"].map("${:,.2f}".format)
popular_item_summary.head(150)
# Out:
#                                             Purchase Count Item Price  \
# Item ID Item Name
# 0       Splinter                                         4      $1.28
# 1       Crucifer                                         3      $3.26
# 2       Verdict                                          6      $2.48
# 3       Phantomlight                                     6      $2.49
# 4       Bloodlord's Fetish                               5      $1.70
# ...                                                    ...        ...
# 146     Warped Iron Scimitar                             5      $3.10
# 147     Hellreaver, Heirloom of Inception                3      $4.93
# 148     Warmonger, Gift of Suffering's End               3      $4.03
# 149     Tranquility, Razor of Black Magic                5      $1.75
# 150     Deathraze                                        5      $2.85
#
#                                            Total Purchase
# Item ID Item Name
# 0       Splinter                                    $5.12
# 1       Crucifer                                    $9.78
# 2       Verdict                                    $14.88
# 3       Phantomlight                               $14.94
# 4       Bloodlord's Fetish                          $8.50
# ...                                                   ...
# 146     Warped Iron Scimitar                       $15.50
# 147     Hellreaver, Heirloom of Inception          $14.79
# 148     Warmonger, Gift of Suffering's End         $12.09
# 149     Tranquility, Razor of Black Magic           $8.75
# 150     Deathraze                                  $14.25
#
# [150 rows x 3 columns]

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
profitable_item = popular_item_summary.sort_values("Total Purchase",ascending= False)

profitable_item.head(150)
# Out:
#                                            Purchase Count Item Price  \
# Item ID Item Name
# 63      Stormfury Mace                                  2      $4.99
# 29      Chaos, Ender of the End                         5      $1.98
# 173     Stormfury Longsword                             2      $4.93
# 1       Crucifer                                        3      $3.26
# 38      The Void, Vengeance of Dark Magic               4      $2.37
# ...                                                   ...        ...
# 150     Deathraze                                       5      $2.85
# 95      Singed Onyx Warscythe                           3      $4.74
# 16      Restored Bauble                                 4      $3.55
# 94      Mourning Blade                                  4      $3.49
# 89      Blazefury, Protector of Delusions               3      $4.64
#
#                                           Total Purchase
# Item ID Item Name
# 63      Stormfury Mace                             $9.98
# 29      Chaos, Ender of the End                    $9.90
# 173     Stormfury Longsword                        $9.86
# 1       Crucifer                                   $9.78
# 38      The Void, Vengeance of Dark Magic          $9.48
# ...                                                  ...
# 150     Deathraze                                 $14.25
# 95      Singed Onyx Warscythe                     $14.22
# 16      Restored Bauble                           $14.20
# 94      Mourning Blade                            $13.96
# 89      Blazefury, Protector of Delusions         $13.92
#
# [150 rows x 3 columns]
